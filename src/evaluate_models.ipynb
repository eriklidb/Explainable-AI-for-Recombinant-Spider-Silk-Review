# %%
import sys
print(sys.executable)
# !which python
# Out:
# c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\spidro_env\Scripts\python.exe
# 'which' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from model_trainer import *
from dataset import Dataset
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap
from scipy.stats import normaltest, ttest_rel, wilcoxon
from tqdm import tqdm
from collections import defaultdict

sns.set_theme(context="paper", style="white", palette="deep")
seed = 42

scaler = 'minmax'
ds = {}
ds['reg'] = Dataset('spinning_data.csv', scaler=scaler)
ds['pca'] = Dataset('spinning_data_embeddings_pca.csv', scaler=scaler)
ds['reg_pp'] = Dataset('spinning_data.csv', scaler=scaler, preprocess=True)
ds['pca_pp'] = Dataset('spinning_data_embeddings_pca.csv', scaler=scaler, preprocess=True)

#cv_type = 'kfold'
cv_type = 'groupkfold'
n_folds = 3
n_inner_folds = 5
mt = ModelTrainer(n_outer_folds=n_folds, n_inner_folds=n_inner_folds, cv_type=cv_type, random_state=seed)
models = {}
baseline = None
targets = ds['reg'].target_columns
targets_ordered = 'Strength (MPa)', 'Strain (mm/mm)', 'Toughness Modulus (MJ m-3)', 'Diameter (µm)', 'Youngs Modulus (GPa)'
targets_print = 'Strength', 'Strain', 'Toughness', 'Diameter', '$E$'
targets_print_lower = 'strength', 'strain', 'toughness', 'diameter', '$E$'

TRAIN_MODELS = True
MODELS = ['lr', 'rr', 'rfr', 'etr', 'hgbr', 'xgbr', 'cbr', 'knnr']
final_model = 'etr'
ds['A'] = ds['reg_pp']
ds['B'] = ds['pca_pp']

# %%
print(ds['reg'].df.loc[:, 'Protein'].value_counts(normalize=True))
print(ds['reg'].df.loc[:, 'Protein'].value_counts(normalize=False))
# Out:
# Protein
# A3IA                                0.526484
# NT2RepCT                            0.204566
# Rep3                                0.031507
# Rep2                                0.027397
# Rep5                                0.027397
# Rep1                                0.027397
# 4A 2rep                             0.026941
# Rep7                                0.026941
# NT2RepCT + 50 uM Tht                0.013699
# VN-A3IA                             0.013699
# fNT A3IA                            0.010046
# Rep7 Tusp (57%) & NT2repCT (43%)    0.009132
# Rep7 Tusp (30%) & NT2RepCT (70%)    0.009132
# Rep4                                0.009132
# NT2RepCT 0.1% Bri2MCherry           0.004566
# NT2RepCT 0.5% Bri2MCherry           0.004566
# 5% VN-NT & A3IA                     0.004566
# Br_MaSp2_short                      0.004566
# Br_MaSp2_400                        0.004566
# Br_MaSp2_long                       0.004566
# Br_MaSp2_300                        0.004566
# A3I-A +0.1% Carbon Black            0.004110
# NT2RepCT -Magnetic nanoparticles    0.000457
# Name: proportion, dtype: float64
# Protein
# A3IA                                1153
# NT2RepCT                             448
# Rep3                                  69
# Rep2                                  60
# Rep5                                  60
# Rep1                                  60
# 4A 2rep                               59
# Rep7                                  59
# NT2RepCT + 50 uM Tht                  30
# VN-A3IA                               30
# fNT A3IA                              22
# Rep7 Tusp (57%) & NT2repCT (43%)      20
# Rep7 Tusp (30%) & NT2RepCT (70%)      20
# Rep4                                  20
# NT2RepCT 0.1% Bri2MCherry             10
# NT2RepCT 0.5% Bri2MCherry             10
# 5% VN-NT & A3IA                       10
# Br_MaSp2_short                        10
# Br_MaSp2_400                          10
# Br_MaSp2_long                         10
# Br_MaSp2_300                          10
# A3I-A +0.1% Carbon Black               9
# NT2RepCT -Magnetic nanoparticles       1
# Name: count, dtype: int64

# %%
print(f'Number of rows: {len(ds['reg'])}')
print(f'Number of columns: {len(ds['reg'].columns)}')
print(f'Number of columns (PCA): {len(ds['pca'].columns)}')
#print(ds['reg'].df.loc[:,'Protein'].value_counts(normalize=True))
#print(ds['reg'].df.loc[:,'Sample number'].value_counts(normalize=False).to_string())
# Out:
# Number of rows: 2190
# Number of columns: 24
# Number of columns (PCA): 39

# %%
TRAIN_BASELINE = defaultdict(lambda: False)
TRAIN_BASELINE['lr'] = True
TRAIN_BASELINE['rr'] = True
TRAIN_BASELINE['rfr'] = True
TRAIN_BASELINE['etr'] = True
TRAIN_BASELINE['hgbr'] = True
TRAIN_BASELINE['xgbr'] = True
TRAIN_BASELINE['cbr'] = True
TRAIN_BASELINE['knnr'] = True

BASELINE_DS = {}
BASELINE_DS['lr'] = ds['reg_pp']
BASELINE_DS['rr'] = ds['reg_pp']
BASELINE_DS['rfr'] = ds['reg_pp']
BASELINE_DS['etr'] = ds['reg_pp']
BASELINE_DS['hgbr'] = ds['reg']
BASELINE_DS['xgbr'] = ds['reg_pp']
BASELINE_DS['cbr'] = ds['reg']
BASELINE_DS['knnr'] = ds['reg_pp']

N_TRAILS = defaultdict(lambda: 1)
N_TRAILS['rr'] = 10
N_TRAILS['rfr'] = 30
N_TRAILS['etr'] = 30
N_TRAILS['hgbr'] = 50
N_TRAILS['xgdr'] = 50
N_TRAILS['cbr'] = 30
N_TRAILS['knnr'] = 20

#for m in MODELS:
baseline_models = {}
for m in MODELS:
    if TRAIN_BASELINE[m]:
        study_params = {
            'n_trails': N_TRAILS[m],
            'timeout': 1800,
            'n_jobs': -1
        }
        baseline_models[m] = {}
        for target in targets:
            if m == 'lr':
                baseline_models[m][target] = mt.train_model(BASELINE_DS[m], m, target=target)
            else:
                model_params = mt.hyperparameter_search(BASELINE_DS[m], m, study_name=f"{m}_{target}", **study_params, target=target)
                baseline_models[m][target] = mt.train_model(BASELINE_DS[m], m, model_params, target=target)
            for i, model in enumerate(baseline_models[m][target]):
                save_model(model, f'../models/baselines/{m}_fold_{i}_{target.split()[0]}')
# Out:
# [I 2026-07-13 02:33:38,213] A new study created in memory with name: rr_Diameter (µm)_0_Diameter (µm)
# [I 2026-07-13 02:33:38,365] Trial 0 finished with value: 0.08752804439743782 and parameters: {'alpha': 0.25309676248169094, 'fit_intercept': False}. Best is trial 0 with value: 0.08752804439743782.
# [I 2026-07-13 02:33:38,383] Trial 1 finished with value: 0.08284764608649076 and parameters: {'alpha': 16.89421433655263, 'fit_intercept': False}. Best is trial 1 with value: 0.08284764608649076.
# [I 2026-07-13 02:33:38,401] Trial 4 finished with value: 0.08007046713884076 and parameters: {'alpha': 42.42597927499386, 'fit_intercept': False}. Best is trial 4 with value: 0.08007046713884076.
# [I 2026-07-13 02:33:38,405] Trial 2 finished with value: 0.07839315453150689 and parameters: {'alpha': 85.56397469214386, 'fit_intercept': True}. Best is trial 2 with value: 0.07839315453150689.
# [I 2026-07-13 02:33:38,407] Trial 3 finished with value: 0.07818681638868882 and parameters: {'alpha': 95.3161373205751, 'fit_intercept': True}. Best is trial 3 with value: 0.07818681638868882.
# [I 2026-07-13 02:33:38,415] Trial 7 finished with value: 0.07954916261933116 and parameters: {'alpha': 52.102331442540525, 'fit_intercept': True}. Best is trial 3 with value: 0.07818681638868882.
# [I 2026-07-13 02:33:38,423] Trial 6 finished with value: 0.07891944269841797 and parameters: {'alpha': 67.07766475304955, 'fit_intercept': True}. Best is trial 3 with value: 0.07818681638868882.
# [I 2026-07-13 02:33:38,426] Trial 5 finished with value: 0.08652934326548621 and parameters: {'alpha': 1.6003801780024953, 'fit_intercept': True}. Best is trial 3 with value: 0.07818681638868882.
# [I 2026-07-13 02:33:38,477] Trial 8 finished with value: 0.0786507872604438 and parameters: {'alpha': 75.58907306425748, 'fit_intercept': True}. Best is trial 3 with value: 0.07818681638868882.
# [I 2026-07-13 02:33:38,487] Trial 9 finished with value: 0.07838852250421217 and parameters: {'alpha': 85.76355152918428, 'fit_intercept': True}. Best is trial 3 with value: 0.07818681638868882.
# [I 2026-07-13 02:33:38,494] A new study created in memory with name: rr_Diameter (µm)_1_Diameter (µm)
# [I 2026-07-13 02:33:38,641] Trial 1 finished with value: 0.07329371295203636 and parameters: {'alpha': 86.09394088969565, 'fit_intercept': False}. Best is trial 1 with value: 0.07329371295203636.
# [I 2026-07-13 02:33:38,652] Trial 0 finished with value: 0.07291469306102817 and parameters: {'alpha': 25.051395160834602, 'fit_intercept': True}. Best is trial 0 with value: 0.07291469306102817.
# [I 2026-07-13 02:33:38,668] Trial 4 finished with value: 0.07291266988942038 and parameters: {'alpha': 32.45726812286017, 'fit_intercept': False}. Best is trial 4 with value: 0.07291266988942038.
# [I 2026-07-13 02:33:38,684] Trial 7 finished with value: 0.0733094989658077 and parameters: {'alpha': 88.47510092121152, 'fit_intercept': False}. Best is trial 4 with value: 0.07291266988942038.
# [I 2026-07-13 02:33:38,691] Trial 2 finished with value: 0.07311133759397863 and parameters: {'alpha': 58.39896352735411, 'fit_intercept': True}. Best is trial 4 with value: 0.07291266988942038.
# [I 2026-07-13 02:33:38,712] Trial 3 finished with value: 0.07317831726426363 and parameters: {'alpha': 67.3878392073921, 'fit_intercept': True}. Best is trial 4 with value: 0.07291266988942038.
# [I 2026-07-13 02:33:38,715] Trial 6 finished with value: 0.07291485778584601 and parameters: {'alpha': 24.68764871858473, 'fit_intercept': True}. Best is trial 4 with value: 0.07291266988942038.
# [I 2026-07-13 02:33:38,733] Trial 5 finished with value: 0.07291723198297254 and parameters: {'alpha': 27.768648599903045, 'fit_intercept': True}. Best is trial 4 with value: 0.07291266988942038.
# [I 2026-07-13 02:33:38,765] Trial 9 finished with value: 0.07296245099031624 and parameters: {'alpha': 40.94579114001043, 'fit_intercept': False}. Best is trial 4 with value: 0.07291266988942038.
# [I 2026-07-13 02:33:38,767] Trial 8 finished with value: 0.07319977815039427 and parameters: {'alpha': 9.394441590993837, 'fit_intercept': False}. Best is trial 4 with value: 0.07291266988942038.
# [I 2026-07-13 02:33:38,773] A new study created in memory with name: rr_Diameter (µm)_2_Diameter (µm)
# [I 2026-07-13 02:33:38,900] Trial 0 finished with value: 0.07468807151237751 and parameters: {'alpha': 89.44886322634713, 'fit_intercept': False}. Best is trial 0 with value: 0.07468807151237751.
# [I 2026-07-13 02:33:38,937] Trial 1 finished with value: 0.07441789201284721 and parameters: {'alpha': 43.064415098922254, 'fit_intercept': False}. Best is trial 1 with value: 0.07441789201284721.
# [I 2026-07-13 02:33:38,964] Trial 7 finished with value: 0.0744029889973491 and parameters: {'alpha': 22.284287967710636, 'fit_intercept': False}. Best is trial 7 with value: 0.0744029889973491.
# [I 2026-07-13 02:33:38,972] Trial 4 finished with value: 0.07478893227394587 and parameters: {'alpha': 97.63031403187993, 'fit_intercept': True}. Best is trial 7 with value: 0.0744029889973491.
# [I 2026-07-13 02:33:38,979] Trial 5 finished with value: 0.07563061771580255 and parameters: {'alpha': 3.7495680223288006, 'fit_intercept': True}. Best is trial 7 with value: 0.0744029889973491.
# [I 2026-07-13 02:33:38,979] Trial 6 finished with value: 0.0745230629385204 and parameters: {'alpha': 51.868100208699296, 'fit_intercept': True}. Best is trial 7 with value: 0.0744029889973491.
# [I 2026-07-13 02:33:38,981] Trial 2 finished with value: 0.07458395197009532 and parameters: {'alpha': 61.903545896099615, 'fit_intercept': True}. Best is trial 7 with value: 0.0744029889973491.
# [I 2026-07-13 02:33:38,982] Trial 3 finished with value: 0.07442795412424694 and parameters: {'alpha': 28.001450560037338, 'fit_intercept': True}. Best is trial 7 with value: 0.0744029889973491.
# [I 2026-07-13 02:33:39,032] Trial 8 finished with value: 0.07443648547345674 and parameters: {'alpha': 24.151868381748336, 'fit_intercept': True}. Best is trial 7 with value: 0.0744029889973491.
# [I 2026-07-13 02:33:39,037] Trial 9 finished with value: 0.07465236178377169 and parameters: {'alpha': 83.11760536359095, 'fit_intercept': False}. Best is trial 7 with value: 0.0744029889973491.
# [I 2026-07-13 02:33:39,065] A new study created in memory with name: rr_Strain (mm/mm)_0_Strain (mm/mm)
# [I 2026-07-13 02:33:39,232] Trial 0 finished with value: 0.21776015211182215 and parameters: {'alpha': 47.05412260581523, 'fit_intercept': True}. Best is trial 0 with value: 0.21776015211182215.
# [I 2026-07-13 02:33:39,243] Trial 1 finished with value: 0.22258911943947934 and parameters: {'alpha': 22.252955746307993, 'fit_intercept': False}. Best is trial 0 with value: 0.21776015211182215.
# [I 2026-07-13 02:33:39,262] Trial 3 finished with value: 0.2188035481451117 and parameters: {'alpha': 37.033678424382906, 'fit_intercept': False}. Best is trial 0 with value: 0.21776015211182215.
# [I 2026-07-13 02:33:39,263] Trial 4 finished with value: 0.22464283339654245 and parameters: {'alpha': 18.162562658352794, 'fit_intercept': False}. Best is trial 0 with value: 0.21776015211182215.
# [I 2026-07-13 02:33:39,274] Trial 7 finished with value: 0.21664795315577887 and parameters: {'alpha': 89.02061414889842, 'fit_intercept': False}. Best is trial 7 with value: 0.21664795315577887.
# [I 2026-07-13 02:33:39,278] Trial 6 finished with value: 0.21764275482448325 and parameters: {'alpha': 48.63232863425464, 'fit_intercept': True}. Best is trial 7 with value: 0.21664795315577887.
# [I 2026-07-13 02:33:39,281] Trial 5 finished with value: 0.2263011733787092 and parameters: {'alpha': 15.750518992243943, 'fit_intercept': True}. Best is trial 7 with value: 0.21664795315577887.
# [I 2026-07-13 02:33:39,283] Trial 2 finished with value: 0.22247315371208062 and parameters: {'alpha': 22.668250775824607, 'fit_intercept': True}. Best is trial 7 with value: 0.21664795315577887.
# [I 2026-07-13 02:33:39,343] Trial 9 finished with value: 0.24587335834156315 and parameters: {'alpha': 3.603308217783313, 'fit_intercept': False}. Best is trial 7 with value: 0.21664795315577887.
# [I 2026-07-13 02:33:39,346] Trial 8 finished with value: 0.21670679321632233 and parameters: {'alpha': 79.63555632755669, 'fit_intercept': True}. Best is trial 7 with value: 0.21664795315577887.
# [I 2026-07-13 02:33:39,351] A new study created in memory with name: rr_Strain (mm/mm)_1_Strain (mm/mm)
# [I 2026-07-13 02:33:39,492] Trial 2 finished with value: 0.2033550659438867 and parameters: {'alpha': 87.36844863626953, 'fit_intercept': False}. Best is trial 2 with value: 0.2033550659438867.
# [I 2026-07-13 02:33:39,515] Trial 1 finished with value: 0.1986224766329034 and parameters: {'alpha': 27.49606812358093, 'fit_intercept': False}. Best is trial 1 with value: 0.1986224766329034.
# [I 2026-07-13 02:33:39,519] Trial 3 finished with value: 0.20247706322763062 and parameters: {'alpha': 73.3865291246938, 'fit_intercept': False}. Best is trial 1 with value: 0.1986224766329034.
# [I 2026-07-13 02:33:39,529] Trial 5 finished with value: 0.20284340390440653 and parameters: {'alpha': 78.99550792699306, 'fit_intercept': False}. Best is trial 1 with value: 0.1986224766329034.
# [I 2026-07-13 02:33:39,530] Trial 6 finished with value: 0.19859029718568927 and parameters: {'alpha': 1.1728328991132204, 'fit_intercept': False}. Best is trial 6 with value: 0.19859029718568927.
# [I 2026-07-13 02:33:39,532] Trial 0 finished with value: 0.2029788977804919 and parameters: {'alpha': 79.88552108726499, 'fit_intercept': True}. Best is trial 6 with value: 0.19859029718568927.
# [I 2026-07-13 02:33:39,549] Trial 4 finished with value: 0.20234603227074385 and parameters: {'alpha': 70.32214714245467, 'fit_intercept': True}. Best is trial 6 with value: 0.19859029718568927.
# [I 2026-07-13 02:33:39,590] Trial 7 finished with value: 0.20332295898892677 and parameters: {'alpha': 85.47452494369732, 'fit_intercept': True}. Best is trial 6 with value: 0.19859029718568927.
# [I 2026-07-13 02:33:39,623] Trial 9 finished with value: 0.20123769059487612 and parameters: {'alpha': 56.41375842331135, 'fit_intercept': False}. Best is trial 6 with value: 0.19859029718568927.
# [I 2026-07-13 02:33:39,628] Trial 8 finished with value: 0.19948255737738838 and parameters: {'alpha': 35.54404304157292, 'fit_intercept': True}. Best is trial 6 with value: 0.19859029718568927.
# [I 2026-07-13 02:33:39,634] A new study created in memory with name: rr_Strain (mm/mm)_2_Strain (mm/mm)
# [I 2026-07-13 02:33:39,804] Trial 0 finished with value: 0.21294411643497857 and parameters: {'alpha': 28.51392575670774, 'fit_intercept': False}. Best is trial 0 with value: 0.21294411643497857.
# [I 2026-07-13 02:33:39,814] Trial 3 finished with value: 0.21742921486911054 and parameters: {'alpha': 80.64772021344409, 'fit_intercept': False}. Best is trial 0 with value: 0.21294411643497857.
# [I 2026-07-13 02:33:39,827] Trial 7 finished with value: 0.21370131388154623 and parameters: {'alpha': 35.16406481092609, 'fit_intercept': False}. Best is trial 0 with value: 0.21294411643497857.
# [I 2026-07-13 02:33:39,835] Trial 2 finished with value: 0.21553796375048226 and parameters: {'alpha': 54.4615421554727, 'fit_intercept': True}. Best is trial 0 with value: 0.21294411643497857.
# [I 2026-07-13 02:33:39,836] Trial 6 finished with value: 0.21214607971446772 and parameters: {'alpha': 1.3569119223761157, 'fit_intercept': False}. Best is trial 6 with value: 0.21214607971446772.
# [I 2026-07-13 02:33:39,842] Trial 1 finished with value: 0.2175848845755864 and parameters: {'alpha': 83.48223599656444, 'fit_intercept': True}. Best is trial 6 with value: 0.21214607971446772.
# [I 2026-07-13 02:33:39,853] Trial 5 finished with value: 0.21325738102877728 and parameters: {'alpha': 30.886362085079092, 'fit_intercept': True}. Best is trial 6 with value: 0.21214607971446772.
# [I 2026-07-13 02:33:39,861] Trial 4 finished with value: 0.21799787084686684 and parameters: {'alpha': 90.55668288517538, 'fit_intercept': True}. Best is trial 6 with value: 0.21214607971446772.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 44
#      42     baseline_models[m][target] = mt.train_model(BASELINE_DS[m], m, target=target)
#      43 else:
# ---> 44     model_params = mt.hyperparameter_search(BASELINE_DS[m], m, study_name=f"{m}_{target}", **study_params, target=target)
#      45     baseline_models[m][target] = mt.train_model(BASELINE_DS[m], m, model_params, target=target)
#      46 for i, model in enumerate(baseline_models[m][target]):
#
# File c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\src\model_trainer.py:176, in ModelTrainer.hyperparameter_search(self, ds, model_type, target, n_trails, timeout, n_jobs, study_name)
#     174 study_name_ = None if study_name is None else f'{study_name}_{outer_fold}_{target}'
#     175 study = optuna.create_study(direction="minimize", study_name=study_name_, sampler=sampler)
# --> 176 study.optimize(objective, n_trials=n_trails, timeout=timeout, n_jobs=n_jobs)
#     177 best_params.append(study.best_params)
#     179 # Dynamically determine max_iter
#
# File c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\spidro_env\Lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\spidro_env\Lib\site-packages\optuna\study\_optimize.py:102, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      99     break
#     101 if len(futures) >= n_jobs:
# --> 102     completed, futures = wait(futures, return_when=FIRST_COMPLETED)
#     103     # Raise if exception occurred in executing the completed futures.
#     104     for f in completed:
#
# File C:\Python314\Lib\concurrent\futures\_base.py:299, in wait(fs, timeout, return_when)
#     295         return DoneAndNotDoneFutures(done, not_done)
#     297     waiter = _create_and_install_waiters(fs, return_when)
# --> 299 waiter.event.wait(timeout)
#     300 for f in fs:
#     301     with f._condition:
#
# File C:\Python314\Lib\threading.py:670, in Event.wait(self, timeout)
#     668 signaled = self._flag
#     669 if not signaled:
# --> 670     signaled = self._cond.wait(timeout)
#     671 return signaled
#
# File C:\Python314\Lib\threading.py:369, in Condition.wait(self, timeout)
#     367 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     368     if timeout is None:
# --> 369         waiter.acquire()
#     370         gotit = True
#     371     else:
#
# KeyboardInterrupt:

# %%
for m in MODELS:
    models[m] = {}
    for target in targets:
        models[m][target] = [None] * n_folds
        for i in range(n_folds):
            models[m][target][i] = load_model(f'../models/baselines/{m}_fold_{i}_{target.split()[0]}')
            if m == 'hgbr':
                models[m][target][i].categorical_features = BASELINE_DS[m].categorical_columns

# %%
X = {}
X_tot = {}
Y_true = [None] * n_folds
Y_pred = {}
Y_pred_tot = {}
metrics_tot = {}
for m in MODELS:
    X_, Y = BASELINE_DS[m]()
    X[m] = [None] * n_folds
    Y_pred[m] = [None] * n_folds
    for fold, (train_idx, test_idx) in enumerate(mt._outer_cv.split(X_, groups=BASELINE_DS[m].sample_numbers.to_numpy())):
        X[m][fold] = X_.iloc[test_idx].copy()
        Y_true[fold] = Y.iloc[test_idx].copy()
        Y_pred[m][fold] = pd.DataFrame(columns=Y_true[fold].columns)
        for target in targets:
            Y_pred[m][fold].loc[:, target] = models[m][target][fold].predict(X_.iloc[test_idx].copy())
        Y_pred[m][fold] = Y_pred[m][fold].astype(float)
    X_tot[m] = pd.DataFrame(data=np.vstack(X[m]), columns=X_.columns)
    Y_true_tot = pd.DataFrame(data=np.vstack(Y_true), columns=Y.columns)
    Y_pred_tot[m] = pd.DataFrame(data=np.vstack(Y_pred[m]), columns=Y.columns)
    metrics_tot[m] = compute_metrics(Y_true_tot, Y_pred_tot[m])

# %%
for m in MODELS:
    print(m)
    print(metrics_tot[m].to_string())
    print()
    print()
# Out:
# lr
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  Toughness Modulus (MJ m-3)
# RMSE        0.076667        0.220083        0.102913              0.074750                    0.152658
# MAE         0.050682        0.164421        0.073813              0.055677                    0.115463
# $R^2$       0.504672        0.290582        0.184633             -0.051005                    0.224030
# PCC         0.715380        0.579995        0.455760              0.203280                    0.489967
#
#
# rr
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  Toughness Modulus (MJ m-3)
# RMSE        0.074659        0.214379        0.104966              0.071780                    0.151592
# MAE         0.049122        0.165102        0.074120              0.053402                    0.117508
# $R^2$       0.530277        0.326876        0.151780              0.030845                    0.234832
# PCC         0.728701        0.583760        0.422843              0.207149                    0.484749
#
#
# rfr
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  Toughness Modulus (MJ m-3)
# RMSE        0.074564        0.224355        0.096629              0.071442                    0.158253
# MAE         0.050704        0.167083        0.069650              0.052927                    0.120732
# $R^2$       0.531477        0.262775        0.281178              0.039956                    0.166116
# PCC         0.730310        0.529537        0.534914              0.215500                    0.442010
#
#
# etr
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  Toughness Modulus (MJ m-3)
# RMSE        0.074176        0.213582        0.095110              0.072422                    0.153112
# MAE         0.049381        0.161527        0.068102              0.053504                    0.118306
# $R^2$       0.536340        0.331871        0.303591              0.013434                    0.219411
# PCC         0.734131        0.578107        0.551800              0.202744                    0.470596
#
#
# hgbr
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  Toughness Modulus (MJ m-3)
# RMSE        0.077998        0.214311        0.101614              0.072901                    0.162385
# MAE         0.051550        0.161661        0.073745              0.053610                    0.123724
# $R^2$       0.487319        0.327307        0.205092              0.000348                    0.121996
# PCC         0.708847        0.580014        0.498204              0.255393                    0.428547
#
#
# xgbr
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  Toughness Modulus (MJ m-3)
# RMSE        0.098343        0.229241        0.105204              0.072987                    0.170147
# MAE         0.070807        0.186041        0.077199              0.054008                    0.137804
# $R^2$       0.184989        0.230312        0.147933             -0.002019                    0.036052
# PCC         0.526734        0.503645        0.409437             -0.042034                    0.194484
#
#
# cbr
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  Toughness Modulus (MJ m-3)
# RMSE        0.075054        0.212826        0.096305              0.071225                    0.152055
# MAE         0.049075        0.159068        0.069350              0.052262                    0.114623
# $R^2$       0.525289        0.336597        0.285980              0.045776                    0.230155
# PCC         0.726752        0.585483        0.547295              0.284785                    0.487115
#
#
# knnr
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  Toughness Modulus (MJ m-3)
# RMSE        0.077055        0.247491        0.104368              0.077588                    0.175498
# MAE         0.052712        0.181794        0.074442              0.057236                    0.133958
# $R^2$       0.499642        0.102886        0.161424             -0.132328                   -0.025537
# PCC         0.715448        0.433718        0.441880              0.169961                    0.335535

# %%
if TRAIN_MODELS:
    study_params = {
        'n_trails': 2,
        'timeout': 1800,
        'n_jobs': -1
    }
    for k in 'A', 'B':
        models[k] = {}
        for target in targets:
            model_params = mt.hyperparameter_search(ds[k], final_model, study_name=f'{k}_{target}', **study_params, target=target)
            models[k][target] = mt.train_model(ds[k], final_model, model_params, target=target)
            for i, model in enumerate(models[k][target]):
                save_model(model, f'../models/final/{final_model}_{k}_fold_{i}_{target.split()[0]}')
# Out:
# [I 2026-07-13 02:34:24,088] A new study created in memory with name: A_Diameter (µm)_0_Diameter (µm)
# [I 2026-07-13 02:34:28,507] Trial 1 finished with value: 0.07268748349689265 and parameters: {'n_estimators': 364, 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 16, 'max_features': 'log2', 'bootstrap': False}. Best is trial 1 with value: 0.07268748349689265.
# [I 2026-07-13 02:34:30,543] Trial 0 finished with value: 0.07109455935016469 and parameters: {'n_estimators': 982, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 11, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.07109455935016469.
# [I 2026-07-13 02:34:30,549] A new study created in memory with name: A_Diameter (µm)_1_Diameter (µm)
# [I 2026-07-13 02:34:38,760] Trial 0 finished with value: 0.07724540919442541 and parameters: {'n_estimators': 829, 'max_depth': 20, 'min_samples_leaf': 6, 'min_samples_split': 4, 'max_features': None, 'bootstrap': False}. Best is trial 0 with value: 0.07724540919442541.
# [I 2026-07-13 02:34:40,586] Trial 1 finished with value: 0.07460933454184979 and parameters: {'n_estimators': 953, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 15, 'max_features': 0.3, 'bootstrap': True}. Best is trial 1 with value: 0.07460933454184979.
# [I 2026-07-13 02:34:40,592] A new study created in memory with name: A_Diameter (µm)_2_Diameter (µm)
# [I 2026-07-13 02:34:47,358] Trial 0 finished with value: 0.07925166143963672 and parameters: {'n_estimators': 811, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 12, 'max_features': 0.5, 'bootstrap': False}. Best is trial 0 with value: 0.07925166143963672.
# [I 2026-07-13 02:34:48,788] Trial 1 finished with value: 0.07707346577506607 and parameters: {'n_estimators': 829, 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 1 with value: 0.07707346577506607.
# [I 2026-07-13 02:34:51,923] A new study created in memory with name: A_Strain (mm/mm)_0_Strain (mm/mm)
# [I 2026-07-13 02:34:57,506] Trial 1 finished with value: 0.22037468211736785 and parameters: {'n_estimators': 582, 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 8, 'max_features': 0.3, 'bootstrap': False}. Best is trial 1 with value: 0.22037468211736785.
# [I 2026-07-13 02:35:00,412] Trial 0 finished with value: 0.22407953446544288 and parameters: {'n_estimators': 899, 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 1 with value: 0.22037468211736785.
# [I 2026-07-13 02:35:00,420] A new study created in memory with name: A_Strain (mm/mm)_1_Strain (mm/mm)
# [I 2026-07-13 02:35:06,997] Trial 1 finished with value: 0.19919537392328784 and parameters: {'n_estimators': 657, 'max_depth': 5, 'min_samples_leaf': 7, 'min_samples_split': 4, 'max_features': 1.0, 'bootstrap': False}. Best is trial 1 with value: 0.19919537392328784.
# [I 2026-07-13 02:35:07,518] Trial 0 finished with value: 0.20002309115919722 and parameters: {'n_estimators': 841, 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 14, 'max_features': None, 'bootstrap': False}. Best is trial 1 with value: 0.19919537392328784.
# [I 2026-07-13 02:35:07,525] A new study created in memory with name: A_Strain (mm/mm)_2_Strain (mm/mm)
# [I 2026-07-13 02:35:09,665] Trial 1 finished with value: 0.2183378384245273 and parameters: {'n_estimators': 162, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'max_features': None, 'bootstrap': False}. Best is trial 1 with value: 0.2183378384245273.
# [I 2026-07-13 02:35:12,953] Trial 0 finished with value: 0.21609919679981396 and parameters: {'n_estimators': 801, 'max_depth': 30, 'min_samples_leaf': 9, 'min_samples_split': 18, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.21609919679981396.
# [I 2026-07-13 02:35:15,086] A new study created in memory with name: A_Strength (MPa)_0_Strength (MPa)
# [I 2026-07-13 02:35:20,513] Trial 1 finished with value: 0.09735393994760988 and parameters: {'n_estimators': 584, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10, 'max_features': 1.0, 'bootstrap': False}. Best is trial 1 with value: 0.09735393994760988.
# [I 2026-07-13 02:35:22,677] Trial 0 finished with value: 0.09501684982799283 and parameters: {'n_estimators': 858, 'max_depth': 20, 'min_samples_leaf': 9, 'min_samples_split': 19, 'max_features': 1.0, 'bootstrap': True}. Best is trial 0 with value: 0.09501684982799283.
# [I 2026-07-13 02:35:22,683] A new study created in memory with name: A_Strength (MPa)_1_Strength (MPa)
# [I 2026-07-13 02:35:25,523] Trial 0 finished with value: 0.09747512010412437 and parameters: {'n_estimators': 173, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.09747512010412437.
# [I 2026-07-13 02:35:27,309] Trial 1 finished with value: 0.10037070648420672 and parameters: {'n_estimators': 853, 'max_depth': 5, 'min_samples_leaf': 8, 'min_samples_split': 7, 'max_features': 1.0, 'bootstrap': False}. Best is trial 0 with value: 0.09747512010412437.
# [I 2026-07-13 02:35:27,316] A new study created in memory with name: A_Strength (MPa)_2_Strength (MPa)
# [I 2026-07-13 02:35:30,064] Trial 0 finished with value: 0.09763058749122497 and parameters: {'n_estimators': 265, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.09763058749122497.
# [I 2026-07-13 02:35:33,596] Trial 1 finished with value: 0.09844395822642424 and parameters: {'n_estimators': 871, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 3, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.09763058749122497.
# [I 2026-07-13 02:35:35,135] A new study created in memory with name: A_Youngs Modulus (GPa)_0_Youngs Modulus (GPa)
# [I 2026-07-13 02:35:37,672] Trial 1 finished with value: 0.06772810570748136 and parameters: {'n_estimators': 228, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 12, 'max_features': 0.3, 'bootstrap': False}. Best is trial 1 with value: 0.06772810570748136.
# [I 2026-07-13 02:35:40,714] Trial 0 finished with value: 0.06764526539462673 and parameters: {'n_estimators': 830, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 17, 'max_features': 0.3, 'bootstrap': True}. Best is trial 0 with value: 0.06764526539462673.
# [I 2026-07-13 02:35:40,737] A new study created in memory with name: A_Youngs Modulus (GPa)_1_Youngs Modulus (GPa)
# [I 2026-07-13 02:35:42,306] Trial 1 finished with value: 0.0712030383446001 and parameters: {'n_estimators': 109, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 11, 'max_features': 1.0, 'bootstrap': False}. Best is trial 1 with value: 0.0712030383446001.
# [I 2026-07-13 02:35:43,009] Trial 0 finished with value: 0.07015252836192191 and parameters: {'n_estimators': 418, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 12, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.07015252836192191.
# [I 2026-07-13 02:35:43,015] A new study created in memory with name: A_Youngs Modulus (GPa)_2_Youngs Modulus (GPa)
# [I 2026-07-13 02:35:49,442] Trial 1 finished with value: 0.06983999708956685 and parameters: {'n_estimators': 436, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 1 with value: 0.06983999708956685.
# [I 2026-07-13 02:35:49,996] Trial 0 finished with value: 0.06970159935633616 and parameters: {'n_estimators': 990, 'max_depth': 20, 'min_samples_leaf': 7, 'min_samples_split': 18, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.06970159935633616.
# [I 2026-07-13 02:35:52,485] A new study created in memory with name: A_Toughness Modulus (MJ m-3)_0_Toughness Modulus (MJ m-3)
# [I 2026-07-13 02:36:00,258] Trial 1 finished with value: 0.15947107438887834 and parameters: {'n_estimators': 951, 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 5, 'max_features': 1.0, 'bootstrap': False}. Best is trial 1 with value: 0.15947107438887834.
# [I 2026-07-13 02:36:01,255] Trial 0 finished with value: 0.15712907004505955 and parameters: {'n_estimators': 849, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 19, 'max_features': 0.3, 'bootstrap': True}. Best is trial 0 with value: 0.15712907004505955.
# [I 2026-07-13 02:36:01,261] A new study created in memory with name: A_Toughness Modulus (MJ m-3)_1_Toughness Modulus (MJ m-3)
# [I 2026-07-13 02:36:03,291] Trial 1 finished with value: 0.15330553584413578 and parameters: {'n_estimators': 113, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'max_features': 'log2', 'bootstrap': True}. Best is trial 1 with value: 0.15330553584413578.
# [I 2026-07-13 02:36:04,427] Trial 0 finished with value: 0.15287561262126306 and parameters: {'n_estimators': 419, 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.15287561262126306.
# [I 2026-07-13 02:36:04,434] A new study created in memory with name: A_Toughness Modulus (MJ m-3)_2_Toughness Modulus (MJ m-3)
# [I 2026-07-13 02:36:08,768] Trial 1 finished with value: 0.1464451838261079 and parameters: {'n_estimators': 543, 'max_depth': 30, 'min_samples_leaf': 9, 'min_samples_split': 13, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 1 with value: 0.1464451838261079.
# [I 2026-07-13 02:36:09,025] Trial 0 finished with value: 0.1503501986220681 and parameters: {'n_estimators': 422, 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 15, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 1 with value: 0.1464451838261079.
# [I 2026-07-13 02:36:11,059] A new study created in memory with name: B_Diameter (µm)_0_Diameter (µm)
# [I 2026-07-13 02:36:13,640] Trial 1 finished with value: 0.07737739386979384 and parameters: {'n_estimators': 246, 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 16, 'max_features': 'log2', 'bootstrap': False}. Best is trial 1 with value: 0.07737739386979384.
# [I 2026-07-13 02:36:15,182] Trial 0 finished with value: 0.07168184303043737 and parameters: {'n_estimators': 536, 'max_depth': 5, 'min_samples_leaf': 7, 'min_samples_split': 19, 'max_features': 0.5, 'bootstrap': True}. Best is trial 0 with value: 0.07168184303043737.
# [I 2026-07-13 02:36:15,189] A new study created in memory with name: B_Diameter (µm)_1_Diameter (µm)
# [I 2026-07-13 02:36:23,587] Trial 0 finished with value: 0.07613174196645278 and parameters: {'n_estimators': 884, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 14, 'max_features': 0.3, 'bootstrap': False}. Best is trial 0 with value: 0.07613174196645278.
# [I 2026-07-13 02:36:24,560] Trial 1 finished with value: 0.07666445305322976 and parameters: {'n_estimators': 780, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 18, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.07613174196645278.
# [I 2026-07-13 02:36:24,568] A new study created in memory with name: B_Diameter (µm)_2_Diameter (µm)
# [I 2026-07-13 02:36:28,081] Trial 1 finished with value: 0.07716622809793781 and parameters: {'n_estimators': 241, 'max_depth': 30, 'min_samples_leaf': 8, 'min_samples_split': 19, 'max_features': 0.3, 'bootstrap': True}. Best is trial 1 with value: 0.07716622809793781.
# [I 2026-07-13 02:36:31,385] Trial 0 finished with value: 0.07841061439241197 and parameters: {'n_estimators': 911, 'max_depth': 20, 'min_samples_leaf': 9, 'min_samples_split': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 1 with value: 0.07716622809793781.
# [I 2026-07-13 02:36:33,433] A new study created in memory with name: B_Strain (mm/mm)_0_Strain (mm/mm)
# [I 2026-07-13 02:36:41,261] Trial 1 finished with value: 0.21353384628964003 and parameters: {'n_estimators': 867, 'max_depth': 30, 'min_samples_leaf': 9, 'min_samples_split': 9, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 1 with value: 0.21353384628964003.
# [I 2026-07-13 02:36:42,430] Trial 0 finished with value: 0.21499288872976913 and parameters: {'n_estimators': 697, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 14, 'max_features': 0.3, 'bootstrap': True}. Best is trial 1 with value: 0.21353384628964003.
# [I 2026-07-13 02:36:42,442] A new study created in memory with name: B_Strain (mm/mm)_1_Strain (mm/mm)
# [I 2026-07-13 02:36:50,642] Trial 1 finished with value: 0.20377670634707604 and parameters: {'n_estimators': 718, 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 13, 'max_features': None, 'bootstrap': False}. Best is trial 1 with value: 0.20377670634707604.
# [I 2026-07-13 02:36:50,762] Trial 0 finished with value: 0.20403263916974024 and parameters: {'n_estimators': 756, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'max_features': 1.0, 'bootstrap': False}. Best is trial 1 with value: 0.20377670634707604.
# [I 2026-07-13 02:36:50,768] A new study created in memory with name: B_Strain (mm/mm)_2_Strain (mm/mm)
# [I 2026-07-13 02:36:59,620] Trial 0 finished with value: 0.204482462468745 and parameters: {'n_estimators': 914, 'max_depth': None, 'min_samples_leaf': 7, 'min_samples_split': 4, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.204482462468745.
# [I 2026-07-13 02:37:01,735] Trial 1 finished with value: 0.2097441011059284 and parameters: {'n_estimators': 960, 'max_depth': 30, 'min_samples_leaf': 9, 'min_samples_split': 14, 'max_features': 1.0, 'bootstrap': True}. Best is trial 0 with value: 0.204482462468745.
# [I 2026-07-13 02:37:04,731] A new study created in memory with name: B_Strength (MPa)_0_Strength (MPa)
# [I 2026-07-13 02:37:11,638] Trial 1 finished with value: 0.09474814969719794 and parameters: {'n_estimators': 594, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 7, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 1 with value: 0.09474814969719794.
# [I 2026-07-13 02:37:12,978] Trial 0 finished with value: 0.09636153738794126 and parameters: {'n_estimators': 981, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 7, 'max_features': None, 'bootstrap': False}. Best is trial 1 with value: 0.09474814969719794.
# [I 2026-07-13 02:37:12,985] A new study created in memory with name: B_Strength (MPa)_1_Strength (MPa)
# [I 2026-07-13 02:37:15,139] Trial 0 finished with value: 0.09939363070265347 and parameters: {'n_estimators': 175, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 11, 'max_features': 1.0, 'bootstrap': False}. Best is trial 0 with value: 0.09939363070265347.
# [I 2026-07-13 02:37:15,830] Trial 1 finished with value: 0.10023265239712904 and parameters: {'n_estimators': 299, 'max_depth': 30, 'min_samples_leaf': 10, 'min_samples_split': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.09939363070265347.
# [I 2026-07-13 02:37:15,837] A new study created in memory with name: B_Strength (MPa)_2_Strength (MPa)
# [I 2026-07-13 02:37:18,318] Trial 1 finished with value: 0.09752205762483482 and parameters: {'n_estimators': 155, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 20, 'max_features': 0.5, 'bootstrap': True}. Best is trial 1 with value: 0.09752205762483482.
# [I 2026-07-13 02:37:20,503] Trial 0 finished with value: 0.0981150133206522 and parameters: {'n_estimators': 601, 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 19, 'max_features': 1.0, 'bootstrap': True}. Best is trial 1 with value: 0.09752205762483482.
# [I 2026-07-13 02:37:21,596] A new study created in memory with name: B_Youngs Modulus (GPa)_0_Youngs Modulus (GPa)
# [I 2026-07-13 02:37:26,178] Trial 1 finished with value: 0.06698368338480742 and parameters: {'n_estimators': 476, 'max_depth': 20, 'min_samples_leaf': 8, 'min_samples_split': 19, 'max_features': 'log2', 'bootstrap': False}. Best is trial 1 with value: 0.06698368338480742.
# [I 2026-07-13 02:37:26,446] Trial 0 finished with value: 0.06714753757706628 and parameters: {'n_estimators': 612, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 11, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 1 with value: 0.06698368338480742.
# [I 2026-07-13 02:37:26,453] A new study created in memory with name: B_Youngs Modulus (GPa)_1_Youngs Modulus (GPa)
# [I 2026-07-13 02:37:31,575] Trial 0 finished with value: 0.07045117949379116 and parameters: {'n_estimators': 346, 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 14, 'max_features': 0.3, 'bootstrap': True}. Best is trial 0 with value: 0.07045117949379116.
# [I 2026-07-13 02:37:32,429] Trial 1 finished with value: 0.07091939306124836 and parameters: {'n_estimators': 748, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 14, 'max_features': None, 'bootstrap': False}. Best is trial 0 with value: 0.07045117949379116.
# [I 2026-07-13 02:37:32,436] A new study created in memory with name: B_Youngs Modulus (GPa)_2_Youngs Modulus (GPa)
# [I 2026-07-13 02:37:35,151] Trial 1 finished with value: 0.06961920010203275 and parameters: {'n_estimators': 287, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 17, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 1 with value: 0.06961920010203275.
# [I 2026-07-13 02:37:35,514] Trial 0 finished with value: 0.07025195240845326 and parameters: {'n_estimators': 340, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15, 'max_features': 1.0, 'bootstrap': False}. Best is trial 1 with value: 0.06961920010203275.
# [I 2026-07-13 02:37:36,805] A new study created in memory with name: B_Toughness Modulus (MJ m-3)_0_Toughness Modulus (MJ m-3)
# [I 2026-07-13 02:37:44,972] Trial 1 finished with value: 0.15925227029901 and parameters: {'n_estimators': 789, 'max_depth': 30, 'min_samples_leaf': 10, 'min_samples_split': 17, 'max_features': 1.0, 'bootstrap': False}. Best is trial 1 with value: 0.15925227029901.
# [I 2026-07-13 02:37:45,104] Trial 0 finished with value: 0.15582158689109976 and parameters: {'n_estimators': 940, 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 8, 'max_features': 0.5, 'bootstrap': False}. Best is trial 0 with value: 0.15582158689109976.
# [I 2026-07-13 02:37:45,110] A new study created in memory with name: B_Toughness Modulus (MJ m-3)_1_Toughness Modulus (MJ m-3)
# [I 2026-07-13 02:37:47,103] Trial 1 finished with value: 0.1530366611395448 and parameters: {'n_estimators': 130, 'max_depth': 5, 'min_samples_leaf': 8, 'min_samples_split': 13, 'max_features': 0.5, 'bootstrap': False}. Best is trial 1 with value: 0.1530366611395448.
# [I 2026-07-13 02:37:48,093] Trial 0 finished with value: 0.15185854200579021 and parameters: {'n_estimators': 522, 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.15185854200579021.
# [I 2026-07-13 02:37:48,099] A new study created in memory with name: B_Toughness Modulus (MJ m-3)_2_Toughness Modulus (MJ m-3)
# [I 2026-07-13 02:37:55,323] Trial 0 finished with value: 0.14445958986620827 and parameters: {'n_estimators': 673, 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 11, 'max_features': 1.0, 'bootstrap': False}. Best is trial 0 with value: 0.14445958986620827.
# [I 2026-07-13 02:37:55,987] Trial 1 finished with value: 0.14391971635454454 and parameters: {'n_estimators': 989, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'max_features': 0.3, 'bootstrap': False}. Best is trial 1 with value: 0.14391971635454454.

# %%
for k in 'A', 'B':
    models[k] = {}
    for target in targets:
        models[k][target] = [None] * n_folds
        for i in range(n_folds):
            models[k][target][i] = load_model(f'../models/final/{final_model}_{k}_fold_{i}_{target.split()[0]}')
            if final_model == 'hgbr':
                models[k][target][i].categorical_features = ds[k].categorical_columns

# %%
data_stats = pd.DataFrame(index=['Mean', 'SD', 'CV'],  
                          data=[ds['A'].targets.loc[:, targets_ordered].mean(), 
                                ds['A'].targets.loc[:, targets_ordered].std(ddof=1),
                                ds['A'].targets.loc[:, targets_ordered].std(ddof=1) / ds['A'].targets.loc[:, targets_ordered].mean()])\
    .rename(columns=dict(zip(targets_ordered, targets_print)))\
    .map(lambda x: '{:.2E}'.format(x))
print(data_stats.to_latex())
data_stats
# Out:
# \begin{tabular}{llllll}
# \toprule
#  & Strength & Strain & Toughness & Diameter & $E$ \\
# \midrule
# Mean & 2.58E-01 & 3.96E-01 & 2.52E-01 & 1.91E-01 & 1.86E-01 \\
# SD & 1.14E-01 & 2.61E-01 & 1.73E-01 & 1.09E-01 & 7.29E-02 \\
# CV & 4.41E-01 & 6.60E-01 & 6.89E-01 & 5.69E-01 & 3.92E-01 \\
# \bottomrule
# \end{tabular}
#       Strength    Strain Toughness  Diameter       $E$
# Mean  2.58E-01  3.96E-01  2.52E-01  1.91E-01  1.86E-01
# SD    1.14E-01  2.61E-01  1.73E-01  1.09E-01  7.29E-02
# CV    4.41E-01  6.60E-01  6.89E-01  5.69E-01  3.92E-01

# %%
batch_df = {}
df = ds['A'].group_samples()
for key in 'mean', 'std', 'cv':
    batch_df[key] = pd.DataFrame()
for i in range(len(df)):
    # Ignore 1 sample batches (calculated means).
    if len(df.iloc[i, -1]) == 1: 
        continue
    for key in 'mean', 'std', 'cv':
        batch_df[key].at[i, 'Sample number'] = df.at[i, 'Sample number']
    for col in df.iloc[:, -5:].columns:
        batch_df['mean'].at[i, col] = np.mean(df.at[i, col])
        batch_df['std'].at[i, col] = np.std(df.at[i, col], ddof=1)
        batch_df['cv'].at[i, col] = batch_df['std'].at[i, col] / batch_df['mean'].at[i, col]

orientation = 'vertical'
if orientation == 'vertical':
    fig, ax = plt.subplots(3, 1)
    fig.set_figwidth(5)
    fig.set_figheight(10)
    plt.tight_layout(h_pad=3)
else:
    fig, ax = plt.subplots(1, 3)
    fig.set_figwidth(24)
    fig.set_figheight(5)

ax[0].boxplot(batch_df['mean'].loc[:, targets_ordered], tick_labels=targets_print)
ax[0].set_title("Mean per batch", fontsize=15)
ax[0].set_ylabel("Mean", fontsize=13)
ax[0].xaxis.set_tick_params(labelsize=11)
ax[0].yaxis.set_tick_params(labelsize=11)
ax[0].grid(True)

ax[1].boxplot(batch_df['std'].loc[:, targets_ordered], tick_labels=targets_print)
ax[1].set_title("Standard deviation per batch", fontsize=15)
ax[1].set_ylabel("SD", fontsize=13)
ax[1].xaxis.set_tick_params(labelsize=11)
ax[1].yaxis.set_tick_params(labelsize=11)
ax[1].grid(True)

ax[2].boxplot(batch_df['cv'].loc[:, targets_ordered], tick_labels=targets_print)
ax[2].set_title("Coefficient of variation per property", fontsize=15)
ax[2].set_ylabel("CV", fontsize=13)
ax[2].xaxis.set_tick_params(labelsize=11)
ax[2].yaxis.set_tick_params(labelsize=11)
ax[2].grid(True)

plt.show()
fig.savefig('../figures/label_noise.png', bbox_inches='tight')

# %%
metrics_tot = {}

X = {}
X_tot = {}
Y_true = [None] * n_folds
Y_pred = {}
Y_pred_tot = {}
for k in 'A', 'B':
    X_, Y = ds[k]()
    X[k] = [None] * n_folds
    Y_pred[k] = [None] * n_folds
    for fold, (train_idx, test_idx) in enumerate(mt._outer_cv.split(X_, groups=ds[k].sample_numbers.to_numpy())):
        X[k][fold] = X_.iloc[test_idx].copy()
        Y_true[fold] = Y.iloc[test_idx].copy()
        Y_pred[k][fold] = pd.DataFrame(columns=Y_true[fold].columns)
        for target in targets:
            Y_pred[k][fold].loc[:, target] = models[k][target][fold].predict(X_.iloc[test_idx].copy())
        Y_pred[k][fold] = Y_pred[k][fold].astype(float)
    X_tot[k] = pd.DataFrame(data=np.vstack(X[k]), columns=X_.columns)
    Y_true_tot = pd.DataFrame(data=np.vstack(Y_true), columns=Y.columns)
    Y_pred_tot[k] = pd.DataFrame(data=np.vstack(Y_pred[k]), columns=Y.columns)
    metrics_tot[k] = compute_metrics(Y_true_tot, Y_pred_tot[k])

# %%
df_A = metrics_tot['A'].loc[:, targets_ordered]
df_B = metrics_tot['B'].loc[:, targets_ordered]
table = pd.DataFrame(index=targets_print,
                     columns=np.tile(['Spin', 'Seq', r'$\Delta$'], 4), 
                     data=np.vstack((df_A.iloc[0, :].to_numpy(), df_B.iloc[0, :].to_numpy(), df_B.iloc[0, :].to_numpy() - df_A.iloc[0, :].to_numpy(),
                                     df_A.iloc[1, :].to_numpy(), df_B.iloc[1, :].to_numpy(), df_B.iloc[1, :].to_numpy() - df_A.iloc[1, :].to_numpy(),
                                     df_A.iloc[2, :].to_numpy(), df_B.iloc[2, :].to_numpy(), df_B.iloc[2, :].to_numpy() - df_A.iloc[2, :].to_numpy(),
                                     df_A.iloc[3, :].to_numpy(), df_B.iloc[3, :].to_numpy(), df_B.iloc[3, :].to_numpy() - df_A.iloc[3, :].to_numpy())).T).map(lambda x: '{:.2E}'.format(x))
print(table.to_latex())
print(table.T.to_latex())
table
# Out:
# \begin{tabular}{lllllllllllll}
# \toprule
#  & Spin & Seq & $\Delta$ & Spin & Seq & $\Delta$ & Spin & Seq & $\Delta$ & Spin & Seq & $\Delta$ \\
# \midrule
# Strength & 9.56E-02 & 9.77E-02 & 2.03E-03 & 6.93E-02 & 6.98E-02 & 5.47E-04 & 2.96E-01 & 2.66E-01 & -3.02E-02 & 5.47E-01 & 5.19E-01 & -2.76E-02 \\
# Strain & 2.20E-01 & 2.15E-01 & -4.92E-03 & 1.63E-01 & 1.63E-01 & -5.63E-04 & 2.92E-01 & 3.24E-01 & 3.13E-02 & 5.56E-01 & 5.74E-01 & 1.82E-02 \\
# Toughness & 1.55E-01 & 1.57E-01 & 1.21E-03 & 1.19E-01 & 1.20E-01 & 1.04E-03 & 1.95E-01 & 1.83E-01 & -1.26E-02 & 4.49E-01 & 4.35E-01 & -1.38E-02 \\
# Diameter & 7.44E-02 & 7.63E-02 & 1.89E-03 & 4.98E-02 & 5.12E-02 & 1.38E-03 & 5.34E-01 & 5.10E-01 & -2.39E-02 & 7.31E-01 & 7.18E-01 & -1.37E-02 \\
# $E$ & 7.08E-02 & 7.19E-02 & 1.19E-03 & 5.24E-02 & 5.34E-02 & 9.95E-04 & 5.84E-02 & 2.64E-02 & -3.21E-02 & 2.59E-01 & 2.32E-01 & -2.73E-02 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llllll}
# \toprule
#  & Strength & Strain & Toughness & Diameter & $E$ \\
# \midrule
# Spin & 9.56E-02 & 2.20E-01 & 1.55E-01 & 7.44E-02 & 7.08E-02 \\
# Seq & 9.77E-02 & 2.15E-01 & 1.57E-01 & 7.63E-02 & 7.19E-02 \\
# $\Delta$ & 2.03E-03 & -4.92E-03 & 1.21E-03 & 1.89E-03 & 1.19E-03 \\
# Spin & 6.93E-02 & 1.63E-01 & 1.19E-01 & 4.98E-02 & 5.24E-02 \\
# Seq & 6.98E-02 & 1.63E-01 & 1.20E-01 & 5.12E-02 & 5.34E-02 \\
# $\Delta$ & 5.47E-04 & -5.63E-04 & 1.04E-03 & 1.38E-03 & 9.95E-04 \\
# Spin & 2.96E-01 & 2.92E-01 & 1.95E-01 & 5.34E-01 & 5.84E-02 \\
# Seq & 2.66E-01 & 3.24E-01 & 1.83E-01 & 5.10E-01 & 2.64E-02 \\
# $\Delta$ & -3.02E-02 & 3.13E-02 & -1.26E-02 & -2.39E-02 & -3.21E-02 \\
# Spin & 5.47E-01 & 5.56E-01 & 4.49E-01 & 7.31E-01 & 2.59E-01 \\
# Seq & 5.19E-01 & 5.74E-01 & 4.35E-01 & 7.18E-01 & 2.32E-01 \\
# $\Delta$ & -2.76E-02 & 1.82E-02 & -1.38E-02 & -1.37E-02 & -2.73E-02 \\
# \bottomrule
# \end{tabular}
#                Spin       Seq   $\Delta$      Spin       Seq   $\Delta$  \
# Strength   9.56E-02  9.77E-02   2.03E-03  6.93E-02  6.98E-02   5.47E-04
# Strain     2.20E-01  2.15E-01  -4.92E-03  1.63E-01  1.63E-01  -5.63E-04
# Toughness  1.55E-01  1.57E-01   1.21E-03  1.19E-01  1.20E-01   1.04E-03
# Diameter   7.44E-02  7.63E-02   1.89E-03  4.98E-02  5.12E-02   1.38E-03
# $E$        7.08E-02  7.19E-02   1.19E-03  5.24E-02  5.34E-02   9.95E-04
#
#                Spin       Seq   $\Delta$      Spin       Seq   $\Delta$
# Strength   2.96E-01  2.66E-01  -3.02E-02  5.47E-01  5.19E-01  -2.76E-02
# Strain     2.92E-01  3.24E-01   3.13E-02  5.56E-01  5.74E-01   1.82E-02
# Toughness  1.95E-01  1.83E-01  -1.26E-02  4.49E-01  4.35E-01  -1.38E-02
# Diameter   5.34E-01  5.10E-01  -2.39E-02  7.31E-01  7.18E-01  -1.37E-02
# $E$        5.84E-02  2.64E-02  -3.21E-02  2.59E-01  2.32E-01  -2.73E-02

# %%
fig = plt.figure(figsize=(8,11))
ax = [plt.subplot2grid(shape=(3,4), loc=(0,0), colspan=2),
    plt.subplot2grid((3,4), (0,2), colspan=2),
    plt.subplot2grid((3,4), (1,0), colspan=2),
    plt.subplot2grid((3,4), (1,2), colspan=2),
    plt.subplot2grid((3,4), (2,1), colspan=2)]
plt.tight_layout(w_pad=3, h_pad=5)

diff = Y_pred_tot['A'].loc[:, targets_ordered] - Y_pred_tot['B'].loc[:, targets_ordered]
for i, target in enumerate(targets_print):
    ax[i].set_title(target, fontsize=18)
    ax[i].set_xlabel(f'Normalized {target}', fontsize=15)
    ax[i].xaxis.set_tick_params(labelsize=13)
    ax[i].set_ylabel('Density', fontsize=15)
    ax[i].yaxis.set_tick_params(labelsize=13)
    sns.kdeplot(ax=ax[i], data=diff.iloc[:, i], color='C1', fill=False, alpha=1.0, linewidth=3.0)
    ax[i].hist(diff.iloc[:, i], bins=30, density=True, color='C0', alpha=.9)
fig.savefig('../figures/differences.png', bbox_inches='tight')
plt.show()
print(normaltest(diff))

result = ttest_rel(Y_pred_tot['A'].loc[:, targets_ordered], Y_pred_tot['B'].loc[:, targets_ordered])
ci=result.confidence_interval()

table=pd.DataFrame(index=[r'$\Delta$ mean', '$t$-statistic', '$p$-value', 'CI-low', 'CI-high'],
                   columns=targets_print,
                   data=[diff.mean().to_numpy(), result.statistic, result.pvalue, ci.low, ci.high]).T.map(lambda x: '{:.2E}'.format(x))

print(table.to_latex())
print(table.T.to_latex())
print(wilcoxon(Y_pred_tot['A'].loc[:, targets_ordered], Y_pred_tot['B'].loc[:, targets_ordered]))
table
# Out:
# NormaltestResult(statistic=array([455.10205678, 449.89524052, 154.58653512, 251.97919489,
#        277.58793734]), pvalue=array([1.49914630e-99, 2.02530205e-98, 2.70371189e-34, 1.92049443e-55,
#        5.27892249e-61]))
# \begin{tabular}{llllll}
# \toprule
#  & $\Delta$ mean & $t$-statistic & $p$-value & CI-low & CI-high \\
# \midrule
# Strength & 2.90E-03 & 7.18E+00 & 9.76E-13 & 2.11E-03 & 3.69E-03 \\
# Strain & -4.19E-03 & -3.55E+00 & 3.94E-04 & -6.50E-03 & -1.87E-03 \\
# Toughness & 6.75E-04 & 1.28E+00 & 2.02E-01 & -3.63E-04 & 1.71E-03 \\
# Diameter & 1.07E-03 & 3.71E+00 & 2.16E-04 & 5.05E-04 & 1.64E-03 \\
# $E$ & 1.14E-03 & 5.45E+00 & 5.64E-08 & 7.29E-04 & 1.55E-03 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llllll}
# \toprule
#  & Strength & Strain & Toughness & Diameter & $E$ \\
# \midrule
# $\Delta$ mean & 2.90E-03 & -4.19E-03 & 6.75E-04 & 1.07E-03 & 1.14E-03 \\
# $t$-statistic & 7.18E+00 & -3.55E+00 & 1.28E+00 & 3.71E+00 & 5.45E+00 \\
# $p$-value & 9.76E-13 & 3.94E-04 & 2.02E-01 & 2.16E-04 & 5.64E-08 \\
# CI-low & 2.11E-03 & -6.50E-03 & -3.63E-04 & 5.05E-04 & 7.29E-04 \\
# CI-high & 3.69E-03 & -1.87E-03 & 1.71E-03 & 1.64E-03 & 1.55E-03 \\
# \bottomrule
# \end{tabular}
#
# WilcoxonResult(statistic=array([1013764., 1162631., 1109956., 1100636.,  975781.]), pvalue=array([3.42258786e-10, 2.11949660e-01, 2.46121636e-03, 8.28834768e-04,
#        3.97753959e-14]))
#           $\Delta$ mean $t$-statistic $p$-value     CI-low    CI-high
# Strength       2.90E-03      7.18E+00  9.76E-13   2.11E-03   3.69E-03
# Strain        -4.19E-03     -3.55E+00  3.94E-04  -6.50E-03  -1.87E-03
# Toughness      6.75E-04      1.28E+00  2.02E-01  -3.63E-04   1.71E-03
# Diameter       1.07E-03      3.71E+00  2.16E-04   5.05E-04   1.64E-03
# $E$            1.14E-03      5.45E+00  5.64E-08   7.29E-04   1.55E-03

# %%
def cohend(d1, d2):
    n1, n2 = len(d1), len(d2)
    s1, s2 = d1.var(ddof=1), d2.var(ddof=1)
    s = np.sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
    u1, u2 = d1.mean(), d2.mean()
    return (u1 - u2) / s
cohend(Y_pred_tot['A'].iloc[:,:], Y_pred_tot['B'].iloc[:,:])
# Out:
# Diameter (µm)                 0.012703
# Strain (mm/mm)               -0.023901
# Strength (MPa)                0.043362
# Youngs Modulus (GPa)          0.042394
# Toughness Modulus (MJ m-3)    0.007572
# dtype: float64

# %%
orientation = ['horizontal', 'horizontal_grid', 'vertical_grid'][1]
palettes = [None, ['g', 'm']]

if orientation == 'horizontal':
    fig, ax = plt.subplots(1, 5)
    fig.set_figwidth(20)
    fig.set_figheight(4)
    plt.tight_layout(w_pad=6)
elif orientation == 'horizontal_grid':
    fig = plt.figure(figsize=(13,8))
    ax = [plt.subplot2grid(shape=(2,6), loc=(0,0), colspan=2),
        plt.subplot2grid((2,6), (0,2), colspan=2),
        plt.subplot2grid((2,6), (0,4), colspan=2),
        plt.subplot2grid((2,6), (1,1), colspan=2),
        plt.subplot2grid((2,6), (1,3), colspan=2)]
    plt.tight_layout(w_pad=6, h_pad=5)
else:
    fig = plt.figure(figsize=(8,11))
    ax = [plt.subplot2grid(shape=(3,4), loc=(0,0), colspan=2),
        plt.subplot2grid((3,4), (0,2), colspan=2),
        plt.subplot2grid((3,4), (1,0), colspan=2),
        plt.subplot2grid((3,4), (1,2), colspan=2),
        plt.subplot2grid((3,4), (2,1), colspan=2)]
    plt.tight_layout(w_pad=6, h_pad=4)

for i, target in enumerate(targets_ordered):
    df = pd.DataFrame(data=np.vstack((Y_true_tot.loc[:, target].to_numpy(), 
                                      Y_pred_tot['A'].loc[:, target].to_numpy(),
                                      Y_pred_tot['A'].loc[:, target].to_numpy())).T,\
        columns=('True', 'Spin', 'Seq'))
    ax[i].set_ylabel(f'Normalized {targets_print_lower[i]}')
    ax[i].set_title((lambda s: s[0].upper() + s[1:])(targets_print[i]), fontsize=20)
    ax[i].xaxis.set_tick_params(labelsize=19)
    ax[i].yaxis.set_tick_params(labelsize=18)
    ax[i].yaxis.label.set_fontsize(20)
    sns.violinplot(ax=ax[i], data=df, palette=palettes[0])

fig.savefig(f'../figures/distribution.png', bbox_inches='tight')
plt.show()

# %%
y_label = ['Normalized actual value', 'Normalized residual']
fname = ['scatter_pred', 'scatter_residual']
orientation = ['horizontal', 'vertical'][1]
for l in range(2):
    if orientation == 'horizontal':
        fig, axs = plt.subplots(2, 5)
        fig.set_figheight(7)
        fig.set_figwidth(20)
        fig.tight_layout(w_pad=4, h_pad=5)
        fontsize=15
    else:
        fig, axs = plt.subplots(5, 2)
        fig.set_figheight(11)
        fig.set_figwidth(6)
        fig.tight_layout(w_pad=5, h_pad=3)
        fontsize=12
    for j, k in enumerate(['A', 'B']):
        for i, target in enumerate(targets_ordered):
            (ii, jj) = (i, j) if orientation == 'horizontal' else (j, i)
            x = Y_pred_tot[k].loc[:, target]
            y = Y_true_tot.loc[:, target] if l == 0 else Y_true_tot.loc[:, target] - Y_pred_tot[k].loc[:, target]
            z = np.polyfit(x, y, 1)
            y_hat = np.poly1d(z)(x)
            #axs[j][i].set_title(f'{target_names[i]}—$\\text{{Model}}^{{\\text{{{'base' if k == 'A' else 'seq'}}}}}$', fontsize=15)
            axs[jj][ii].set_title(f'{'SpinML' if k == 'A' else 'SpinSeqML'}: {targets_print[i]}', fontsize=fontsize)
            axs[jj][ii].set_xlabel('Normalized predicted value', fontsize=fontsize-1)
            axs[jj][ii].set_ylabel(y_label[l], fontsize=fontsize-1)
            axs[jj][ii].xaxis.set_tick_params(labelsize=fontsize-4)
            axs[jj][ii].yaxis.set_tick_params(labelsize=fontsize-4)
            axs[jj][ii].scatter(x, y, c='b', alpha=.25)
            axs[jj][ii].plot(x, y_hat, "r-", lw=1)
            text = r"$y={:0.3f}\;x+{:0.3f}$".format(z[0], z[1]) + "\n" + r"$R^2 = {:0.3f}$".format(metrics_tot[k].loc['$R^2$', target])
            axs[jj][ii].text(0.05, 0.95, text, transform=axs[jj][ii].transAxes,
            fontsize=fontsize-1, verticalalignment='top')
    fig.savefig(f'../figures/{fname[l]}.png', bbox_inches='tight')
    plt.show()

# %%
y_label = ['Normalized actual value', 'Normalized residual']
fname = ['scatter_pred', 'scatter_residual']

for l in range(2):
    fig = plt.figure(figsize=(8,9))
    axs = [plt.subplot2grid(shape=(4,6), loc=(0,0), colspan=2),
        plt.subplot2grid((4,6), (1,0), colspan=2),
        plt.subplot2grid((4,6), (0,2), colspan=2),
        plt.subplot2grid((4,6), (1,2), colspan=2),
        plt.subplot2grid((4,6), (0,4), colspan=2),
        plt.subplot2grid((4,6), (1,4), colspan=2),
        plt.subplot2grid((4,6), (2,1), colspan=2),
        plt.subplot2grid((4,6), (3,1), colspan=2),
        plt.subplot2grid((4,6), (2,3), colspan=2),
        plt.subplot2grid((4,6), (3,3), colspan=2)]
    plt.tight_layout(w_pad=5, h_pad=5)
    fontsize=13
    _n = 0
    for i, target in enumerate(targets_ordered):
        for j, k in enumerate(['A', 'B']):
            color = 'C0' if k == 'A' else 'C1'
            x = Y_pred_tot[k].loc[:, target]
            y = Y_true_tot.loc[:, target] if l == 0 else Y_true_tot.loc[:, target] - Y_pred_tot[k].loc[:, target]
            z = np.polyfit(x, y, 1)
            y_hat = np.poly1d(z)(x)
            axs[_n].set_title(f'{'SpinML' if k == 'A' else 'SpinSeqML'}: {targets_print[i]}', fontsize=fontsize)
            axs[_n].set_xlabel('Normalized predicted value', fontsize=fontsize-1)
            axs[_n].set_ylabel(y_label[l], fontsize=fontsize-1)
            axs[_n].xaxis.set_tick_params(labelsize=fontsize-4)
            axs[_n].yaxis.set_tick_params(labelsize=fontsize-4)
            axs[_n].scatter(x, y, c=color, alpha=.25)
            axs[_n].plot(x, y_hat, "r-", lw=1)
            text = r"$y={:0.3f}\;x+{:0.3f}$".format(z[0], z[1]) + "\n" + r"$R^2 = {:0.3f}$".format(metrics_tot[k].loc['$R^2$', target])
            axs[_n].text(0.05, 0.95, text, transform=axs[_n].transAxes,
            fontsize=fontsize-1, verticalalignment='top')
            _n += 1
    fig.savefig(f'../figures/{fname[l]}.png', bbox_inches='tight')
    plt.show()

# %%
top_features = {}
top_features_avg = {}
for k in 'A', 'B':
    top_features[k] = {}
    combo=True
    #format = 'horizontal'
    format = 'vertical'
    if format == 'horizontal' and combo:
        fig, ax_ = plt.subplots(2, 3)
        ax = [ax_[0][0], ax_[0][1], ax_[0][2], ax_[1][0], ax_[1][1], ax_[1][2]]
        fig.set_figwidth(25)
        fig.set_figheight(10)
        fig.tight_layout(w_pad=30, h_pad=10)
    elif format == 'vertical' and combo:
        fig, ax_ = plt.subplots(3, 2)
        ax = [ax_[0][0], ax_[0][1], ax_[1][0], ax_[1][1], ax_[2][0], ax_[2][1]]
        fig.set_figwidth(13)
        fig.set_figheight(12)
        fig.tight_layout(w_pad=30, h_pad=7)
    else:
        fig = plt.figure(figsize=(17,15))
        ax = [plt.subplot2grid(shape=(3,4), loc=(0,0), colspan=2),
            plt.subplot2grid((3,4), (0,2), colspan=2),
            plt.subplot2grid((3,4), (1,0), colspan=2),
            plt.subplot2grid((3,4), (1,2), colspan=2),
            plt.subplot2grid((3,4), (2,0), colspan=2),
            plt.subplot2grid((3,4), (2,2), colspan=2)] if combo \
            else [plt.subplot2grid(shape=(3,4), loc=(0,0), colspan=2),
            plt.subplot2grid((3,4), (0,2), colspan=2),
            plt.subplot2grid((3,4), (1,0), colspan=2),
            plt.subplot2grid((3,4), (1,2), colspan=2),
            plt.subplot2grid((3,4), (2,1), colspan=2)]
        fig.tight_layout(w_pad=25, h_pad=7)

    max_display=6

    X_encoded = [pd.DataFrame()] * n_folds
    X_encoded_tot = X_tot[k].copy()
    for fold in range(n_folds):
        X_encoded[fold] = X[k][fold].copy() 
        for col in ds[k].categorical_columns:  
            X_encoded[fold][col] = X_encoded[fold][col].astype("category")
            X_encoded[fold][col] = X_encoded[fold][col].cat.codes  # convert to integer codes
        for col in ds[k].numerical_columns:  
            X_encoded[fold][col] = X_encoded[fold][col].astype("float64")
    for col in ds[k].categorical_columns:  
        X_encoded_tot[col] = X_encoded_tot[col].astype("category")
        X_encoded_tot[col] = X_encoded_tot[col].cat.codes  # convert to integer codes

    features = X_encoded_tot.to_numpy().astype('float64')
    base_values = X_encoded_tot.to_numpy().mean(axis=0)

    shap_values_avg = np.zeros(X_encoded_tot.shape)
    # Loop over each target output
    for i, target in enumerate(targets_ordered):
        shap_values = np.zeros(X_encoded_tot.shape)
        for fold in range(n_folds):
            # Compute SHAP values for the input data
            explainer = shap.Explainer(models[k][targets_ordered[i]][fold])
            shap_values[fold*X_encoded[fold].shape[0] : (fold+1)*X_encoded[fold].shape[0]] = explainer(X_encoded[fold]).values
        shap_values_avg += np.abs(shap_values)
        explanation = shap.Explanation(shap_values, feature_names=X_encoded_tot.columns, data=features, base_values=base_values)
        # Plot summary plot
        color_bar = True#i in [1,3,4]
        shap.plots.beeswarm(explanation, max_display=max_display, ax=ax[i], plot_size=None, show=False, color_bar=color_bar)
        ax[i].set_title(f"SHAP values for target: {targets_print[i]}", fontsize=23)
        ax[i].xaxis.set_tick_params(labelsize=21)
        ax[i].yaxis.set_tick_params(labelsize=21)
        ax[i].xaxis.label.set_fontsize(20)
        cbar = fig.axes[-1]
        cbar.tick_params(labelsize=16)
        cbar.set_ylabel('Feature value', fontsize=20)
        top_features_inds = shap_values_avg.mean(axis=0).argsort()[::-1]
        top_features[k][target] = list(X_encoded_tot.columns[top_features_inds])
    shap_values_avg /= 5

    if combo:
        explanation = shap.Explanation(shap_values_avg, feature_names=X_encoded_tot.columns, data=features, base_values=base_values)
        shap.plots.bar(explanation, ax=ax[-1], max_display=max_display, show=False)
        ax[-1].set_title("Mean absolute SHAP values", fontsize=23)
        ax[-1].xaxis.set_tick_params(labelsize=21)
        ax[-1].yaxis.set_tick_params(labelsize=21)
        ax[-1].xaxis.label.set_fontsize(20)
    plt.show()
    fig.savefig(f'../figures/SHAP_{k}.png', bbox_inches='tight')
    top_features_avg_inds = shap_values_avg.mean(axis=0).argsort()[::-1]
    top_features_avg[k] = list(X_encoded_tot.columns[top_features_avg_inds])

# %%
print(top_features_avg)
# Out:
# {'A': ['NaCl (mM)', 'SB pH', 'Temp C (spinning)', 'Protein', 'concentration (mg/ml)', 'Continous spinning', 'Number of baths', 'Reeling speed (rpm)', 'pumppressure (bar)', 'Flow rate (ul/min)', 'Humidity (spinning)', 'Spinning Buffer', 'Capillery size (um)', 'Capillery type', 'Extrusion device', 'Spinning device', 'SB conc. (mM)', 'Temperature SB'], 'B': ['NaCl (mM)', 'Temp C (spinning)', 'Protein', 'SB pH', 'Reeling speed (rpm)', 'concentration (mg/ml)', 'pumppressure (bar)', 'Number of baths', 'Flow rate (ul/min)', 'Continous spinning', 'Humidity (spinning)', 'Capillery size (um)', 'Spinning Buffer', 'Capillery type', 'pca_1', 'pca_8', 'Extrusion device', 'pca_5', 'Spinning device', 'pca_2', 'pca_12', 'pca_6', 'pca_7', 'pca_14', 'pca_4', 'pca_13', 'pca_3', 'pca_9', 'pca_11', 'pca_10', 'SB conc. (mM)', 'pca_15', 'Temperature SB']}

# %%
print(top_features)
# Out:
# {'A': {'Strength (MPa)': ['SB pH', 'concentration (mg/ml)', 'Protein', 'Flow rate (ul/min)', 'Reeling speed (rpm)', 'Temp C (spinning)', 'Continous spinning', 'pumppressure (bar)', 'Humidity (spinning)', 'Spinning Buffer', 'NaCl (mM)', 'Number of baths', 'Spinning device', 'Capillery type', 'Extrusion device', 'Capillery size (um)', 'Temperature SB', 'SB conc. (mM)'], 'Strain (mm/mm)': ['Temp C (spinning)', 'SB pH', 'NaCl (mM)', 'concentration (mg/ml)', 'Protein', 'Continous spinning', 'Number of baths', 'Flow rate (ul/min)', 'Reeling speed (rpm)', 'pumppressure (bar)', 'Humidity (spinning)', 'Spinning Buffer', 'Capillery size (um)', 'Capillery type', 'Spinning device', 'Extrusion device', 'Temperature SB', 'SB conc. (mM)'], 'Toughness Modulus (MJ m-3)': ['NaCl (mM)', 'Temp C (spinning)', 'SB pH', 'Protein', 'concentration (mg/ml)', 'Number of baths', 'Continous spinning', 'Flow rate (ul/min)', 'pumppressure (bar)', 'Reeling speed (rpm)', 'Humidity (spinning)', 'Spinning Buffer', 'Capillery size (um)', 'Capillery type', 'Extrusion device', 'Spinning device', 'SB conc. (mM)', 'Temperature SB'], 'Diameter (µm)': ['NaCl (mM)', 'Temp C (spinning)', 'SB pH', 'Protein', 'concentration (mg/ml)', 'Number of baths', 'pumppressure (bar)', 'Reeling speed (rpm)', 'Continous spinning', 'Flow rate (ul/min)', 'Humidity (spinning)', 'Spinning Buffer', 'Capillery size (um)', 'Capillery type', 'Extrusion device', 'Spinning device', 'SB conc. (mM)', 'Temperature SB'], 'Youngs Modulus (GPa)': ['NaCl (mM)', 'SB pH', 'Temp C (spinning)', 'Protein', 'concentration (mg/ml)', 'Continous spinning', 'Number of baths', 'Reeling speed (rpm)', 'pumppressure (bar)', 'Flow rate (ul/min)', 'Humidity (spinning)', 'Spinning Buffer', 'Capillery size (um)', 'Capillery type', 'Extrusion device', 'Spinning device', 'SB conc. (mM)', 'Temperature SB']}, 'B': {'Strength (MPa)': ['SB pH', 'concentration (mg/ml)', 'Flow rate (ul/min)', 'Protein', 'Reeling speed (rpm)', 'Temp C (spinning)', 'pumppressure (bar)', 'NaCl (mM)', 'Continous spinning', 'Humidity (spinning)', 'Spinning device', 'Number of baths', 'Capillery type', 'pca_5', 'Spinning Buffer', 'Extrusion device', 'pca_2', 'pca_7', 'pca_8', 'Capillery size (um)', 'pca_12', 'pca_11', 'SB conc. (mM)', 'pca_14', 'pca_6', 'pca_3', 'pca_1', 'pca_13', 'pca_10', 'pca_15', 'pca_9', 'pca_4', 'Temperature SB'], 'Strain (mm/mm)': ['Temp C (spinning)', 'Protein', 'concentration (mg/ml)', 'SB pH', 'NaCl (mM)', 'Flow rate (ul/min)', 'Number of baths', 'Continous spinning', 'Reeling speed (rpm)', 'pumppressure (bar)', 'Humidity (spinning)', 'Capillery size (um)', 'Capillery type', 'pca_8', 'Spinning Buffer', 'Spinning device', 'pca_1', 'pca_5', 'Extrusion device', 'pca_2', 'pca_7', 'pca_12', 'pca_4', 'pca_3', 'pca_14', 'pca_6', 'pca_11', 'SB conc. (mM)', 'pca_13', 'pca_10', 'pca_15', 'pca_9', 'Temperature SB'], 'Toughness Modulus (MJ m-3)': ['NaCl (mM)', 'Temp C (spinning)', 'Protein', 'SB pH', 'concentration (mg/ml)', 'Number of baths', 'Flow rate (ul/min)', 'Continous spinning', 'Reeling speed (rpm)', 'pumppressure (bar)', 'Humidity (spinning)', 'Capillery size (um)', 'Spinning Buffer', 'Capillery type', 'pca_8', 'pca_1', 'pca_5', 'Spinning device', 'Extrusion device', 'pca_6', 'pca_7', 'pca_2', 'pca_12', 'pca_3', 'pca_4', 'pca_11', 'pca_14', 'pca_13', 'pca_10', 'SB conc. (mM)', 'pca_9', 'pca_15', 'Temperature SB'], 'Diameter (µm)': ['NaCl (mM)', 'Protein', 'Temp C (spinning)', 'SB pH', 'Reeling speed (rpm)', 'concentration (mg/ml)', 'Number of baths', 'pumppressure (bar)', 'Flow rate (ul/min)', 'Continous spinning', 'Humidity (spinning)', 'Capillery size (um)', 'Spinning Buffer', 'Capillery type', 'pca_8', 'pca_1', 'pca_5', 'Spinning device', 'Extrusion device', 'pca_2', 'pca_12', 'pca_6', 'pca_7', 'pca_3', 'pca_14', 'pca_4', 'pca_11', 'pca_13', 'pca_10', 'pca_9', 'SB conc. (mM)', 'pca_15', 'Temperature SB'], 'Youngs Modulus (GPa)': ['NaCl (mM)', 'Temp C (spinning)', 'Protein', 'SB pH', 'Reeling speed (rpm)', 'concentration ( ...

# %%
a=Y_true_tot.mean().to_numpy().repeat(len(Y_true_tot)).reshape((Y_true_tot.shape[1], Y_true_tot.shape[0])).T
mean_pred = compute_metrics(Y_true_tot, a)
mean_pred
# Out:
# c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\src\model_trainer.py:182: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pearsonr(y_true, y_pred).statistic] # type: ignore
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  \
# RMSE        0.108933        0.261298        0.113971              0.072913
# MAE         0.081433        0.218850        0.083718              0.053848
# $R^2$       0.000000        0.000000        0.000000              0.000000
# PCC              NaN             NaN             NaN                   NaN
#
#        Toughness Modulus (MJ m-3)
# RMSE                     0.173300
# MAE                      0.141437
# $R^2$                    0.000000
# PCC                           NaN

# %%
ds['A'].targets.loc[:,targets_ordered[1]].std()
# Out:
# np.float64(0.2613571953527454)

# %%
data_stats
# Out:
#       Strength    Strain Toughness  Diameter       $E$
# Mean  2.58E-01  3.96E-01  2.52E-01  1.91E-01  1.86E-01
# SD    1.14E-01  2.61E-01  1.73E-01  1.09E-01  7.29E-02
# CV    4.41E-01  6.60E-01  6.89E-01  5.69E-01  3.92E-01

# %%
metrics_tot['B']
# Out:
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  \
# RMSE        0.075005        0.214605        0.096852              0.072581
# MAE         0.050016        0.159792        0.069928              0.053431
# $R^2$       0.525917        0.325458        0.277846              0.009096
# PCC         0.729346        0.581050        0.531451              0.226583
#
#        Toughness Modulus (MJ m-3)
# RMSE                     0.156114
# MAE                      0.120396
# $R^2$                    0.188505
# PCC                      0.438982

# %%
compute_metrics(Y_true_tot, np.zeros(Y_true_tot.shape))
# Out:
# c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\src\model_trainer.py:182: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pearsonr(y_true, y_pred).statistic] # type: ignore
#        Diameter (µm)  Strain (mm/mm)  Strength (MPa)  Youngs Modulus (GPa)  \
# RMSE        0.220290        0.474290        0.282437              0.199770
# MAE         0.191472        0.395822        0.258421              0.185988
# $R^2$      -3.089487       -2.294716       -5.141205             -6.506635
# PCC              NaN             NaN             NaN                   NaN
#
#        Toughness Modulus (MJ m-3)
# RMSE                     0.305599
# MAE                      0.251710
# $R^2$                   -2.109629
# PCC                           NaN

# %%
# Top K features selected from SHAP ranking
k = 'B'
K = 10
use_avg = True
ablation_RMSE = pd.DataFrame(columns=targets)
for K_ in tqdm(range(1, K + 1)):
    if use_avg:
        ds_ablation = {target: Dataset(ds[k].df.loc[:, ['Sample number'] + top_features_avg[k][0:K_] + ds[k].target_columns], scaler=scaler) for i, target in enumerate(targets)}
    else:
        ds_ablation = {target: Dataset(ds[k].df.loc[:, ['Sample number'] + top_features[k][target][0:K_] + ds[k].target_columns], scaler=scaler) for i, target in enumerate(targets)}
    params = {target: [model.get_params() for model in models[k][target]] for target in targets}
    models_ablation = {target: mt.train_model(ds_ablation[target], params[target], target=target) for target in targets}

    Y_ablation_pred = [pd.DataFrame(columns=targets) for _ in range(n_folds)]
    for target in targets:
        X_, Y = ds_ablation[target]()
        for fold, (train_idx, test_idx) in enumerate(mt._outer_cv.split(X_, groups=ds['A'].sample_numbers)):
            Y_ablation_pred[fold].loc[:, target] = models_ablation[target][fold].predict(X_.iloc[test_idx].copy())
    for fold in range(3):
        Y_ablation_pred[fold] = Y_ablation_pred[fold].astype(float)
    Y_ablation_pred_tot = pd.DataFrame(data=np.vstack(Y_ablation_pred), columns=Y.columns)
    metrics_ablation_tot = compute_metrics(Y_true_tot, Y_ablation_pred_tot)
    ablation_RMSE.loc[f'$K_{{{K_}}}$'] = metrics_ablation_tot.loc['RMSE']
ablation_RMSE.loc['A'] = metrics_tot['A'].loc['RMSE']
ablation_RMSE.loc['B'] = metrics_tot['B'].loc['RMSE']
ablation_RMSE.loc['M'] = mean_pred.loc['RMSE']
# Out:
#  60%|██████    | 6/10 [00:16<00:11,  2.76s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 12
#      10     ds_ablation = {target: Dataset(ds[k].df.loc[:, ['Sample number'] + top_features[k][target][0:K_] + ds[k].target_columns], scaler=scaler) for i, target in enumerate(targets)}
#      11 params = {target: [model.get_params() for model in models[k][target]] for target in targets}
# ---> 12 models_ablation = {target: mt.train_model(ds_ablation[target], params[target], target=target) for target in targets}
#      14 Y_ablation_pred = [pd.DataFrame(columns=targets) for _ in range(n_folds)]
#      15 for target in targets:
#
# File c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\src\model_trainer.py:142, in ModelTrainer.train_model(self, ds, params, target)
#     137     params[outer_fold].update({'early_stopping':False,
#     138                 'random_state':self._random_state,
#     139                 'categorical_features':ds.categorical_columns})
#     140     final_model = MultiOutputRegressor(HistGradientBoostingRegressor(**params[outer_fold])) if multioutput else \
#     141         HistGradientBoostingRegressor(**params[outer_fold])
# --> 142     final_model.fit(X_train, Y_train)
#     143     outer_models.append(final_model)
#     144 return outer_models
#
# File c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\spidro_env\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\spidro_env\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:956, in BaseHistGradientBoosting.fit(self, X, y, sample_weight, X_val, y_val, sample_weight_val)
#     936 for k in range(self.n_trees_per_iteration_):
#     937     grower = TreeGrower(
#     938         X_binned=X_binned_train,
#     939         gradients=g_view[:, k],
#    (...)    954         n_threads=n_threads,
#     955     )
# --> 956     grower.grow()
#     958     acc_apply_split_time += grower.total_apply_split_time
#     959     acc_find_split_time += grower.total_find_split_time
#
# File c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\spidro_env\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\grower.py:388, in TreeGrower.grow(self)
#     386 """Grow the tree, from root to leaves."""
#     387 while self.splittable_nodes:
# --> 388     self.split_next()
#     390 self._apply_shrinkage()
#
# File c:\Users\Erik\Repositories\Explainable-AI-for-Recombinant-Spider-Silk-Review\spidro_env\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\grower.py:506, in TreeGrower.split_next(self)
#     499 node = heappop(self.splittable_nodes)
#     501 tic = time()
#     502 (
#     503     sample_indices_left,
#     504     sample_indices_right,
#     505     right_child_pos,
# --> 506 ) = self.splitter.split_indices(node.split_info, node.sample_indices)
#     507 self.total_apply_split_time += time() - tic
#     509 depth = node.depth + 1
#
# KeyboardInterrupt:

# %%
K = 10
inds = list(range(K))
orientation = 'horizontal_grid'
if orientation == 'horizontal':
    fig, ax = plt.subplots(1, 5)
    fig.set_figwidth(22)
    fig.set_figheight(3)
    fig.tight_layout(w_pad=5.5)
elif orientation == 'vertical_grid':
    fig = plt.figure(figsize=(8,11))
    ax = [plt.subplot2grid(shape=(3,4), loc=(0,0), colspan=2),
        plt.subplot2grid((3,4), (0,2), colspan=2),
        plt.subplot2grid((3,4), (1,0), colspan=2),
        plt.subplot2grid((3,4), (1,2), colspan=2),
        plt.subplot2grid((3,4), (2,1), colspan=2)]
    plt.tight_layout(w_pad=5, h_pad=6)
else:
    fig = plt.figure(figsize=(10,6))
    ax = [plt.subplot2grid(shape=(2,6), loc=(0,0), colspan=2),
        plt.subplot2grid((2,6), (0,2), colspan=2),
        plt.subplot2grid((2,6), (0,4), colspan=2),
        plt.subplot2grid((2,6), (1,1), colspan=2),
        plt.subplot2grid((2,6), (1,3), colspan=2)]
    plt.tight_layout(w_pad=5, h_pad=6)
base = [.09, .2, .15, .07, .0715]
x = [str(i) for i in list(range(1, K+1))]
for i, target in enumerate(targets_ordered):
    y = ablation_RMSE.loc[:, target].to_numpy()[inds]
    ax[i].set_title(targets_print[i], fontsize=18)
    ax[i].bar(#x=ablation_RMSE.index[inds].astype(str), 
              x=x,
              height=y - base[i],
              bottom=base[i],
              color='tab:blue',
              alpha=.8)
    ax[i].xaxis.set_tick_params(labelsize=14)
    ax[i].yaxis.set_tick_params(labelsize=14)
    ax[i].set_ylabel('RMSE', fontsize=16)
    ax[i].set_xlabel('Number of features', fontsize=16)

    ax[i].plot(x, y, color='tab:orange', linewidth=3.0)
    ax[i].set_xticks(range(len(ablation_RMSE.iloc[inds])))
plt.show()
fig.savefig('../figures/ablation.png', bbox_inches='tight')

# %%
hyper_params = ['learning_rate', 'max_leaf_nodes', 'min_samples_leaf', 'l2_regularization', 'max_iter']
table = pd.DataFrame(index=hyper_params) 
table.loc[:, 'Range'] = ['$[0.01, 0.3]$', '$[10, 50]$', '$[1, 20]$', '$[0.001, 10]$', r'$[0,\infty)^{\mathrm{a}}$']
for k in 'A', 'B':
    df = pd.DataFrame()
    n = 0
    for i in range(5):
        for j in range(3):
            for h in hyper_params:
                df.loc[n, h] = models[k][targets_ordered[i]][j].get_params()[h]
            n += 1
    table.loc[:, f'Values ${k}$'] = df.mean(axis=0).map(lambda x: '{:.2E}'.format(x)) + ' ± ' + df.std(axis=0, ddof=1).map(lambda x: '{:.2E}'.format(x))
table = table.rename(dict(zip(hyper_params, ['Learning rate', 'Max leafs per tree', 'Minimum samples per leaf', '$L_2$ regularization', 'Maximum iterations'])), axis=0)
print(table.to_latex())
table
# Out:
# \begin{tabular}{llll}
# \toprule
#  & Range & Values $A$ & Values $B$ \\
# \midrule
# Learning rate & $[0.01, 0.3]$ & 1.02E-01 ± 9.43E-02 & 5.13E-02 ± 3.76E-02 \\
# Max leafs per tree & $[10, 50]$ & 1.71E+01 ± 9.54E+00 & 1.86E+01 ± 1.08E+01 \\
# Minimum samples per leaf & $[1, 20]$ & 9.73E+00 ± 7.82E+00 & 8.93E+00 ± 6.88E+00 \\
# $L_2$ regularization & $[0.001, 10]$ & 2.23E+00 ± 3.10E+00 & 1.79E+00 ± 2.64E+00 \\
# Maximum iterations & $[0,\infty)^{\mathrm{a}}$ & 9.11E+01 ± 1.49E+01 & 9.62E+01 ± 1.31E+01 \\
# \bottomrule
# \end{tabular}
#                                               Range           Values $A$  \
# Learning rate                         $[0.01, 0.3]$  1.02E-01 ± 9.43E-02
# Max leafs per tree                       $[10, 50]$  1.71E+01 ± 9.54E+00
# Minimum samples per leaf                  $[1, 20]$  9.73E+00 ± 7.82E+00
# $L_2$ regularization                  $[0.001, 10]$  2.23E+00 ± 3.10E+00
# Maximum iterations        $[0,\infty)^{\mathrm{a}}$  9.11E+01 ± 1.49E+01
#
#                                    Values $B$
# Learning rate             5.13E-02 ± 3.76E-02
# Max leafs per tree        1.86E+01 ± 1.08E+01
# Minimum samples per leaf  8.93E+00 ± 6.88E+00
# $L_2$ regularization      1.79E+00 ± 2.64E+00
# Maximum iterations        9.62E+01 ± 1.31E+01
