# %%
from data_processing import DataProcessing

# %%
dp = DataProcessing()
dp.load_spinning_experiments_excel()
dp.label_unnamed_samples()
dp.label_duplicate_samples()
dp.standardize_columns()
dp.load_targets()
dp.label_duplicate_samples()
dp.merge_targets()
dp.drop_na_targets()
print(dp.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dp = DataProcessing()
#       2 dp.load_spinning_experiments_excel()
#       3 dp.label_unnamed_samples()
#
# NameError: name 'DataProcessing' is not defined

# %% [markdown]
# Control if all sample numbers retrived from the target spreadsheets has a pair with a sample in the spinning conditions experiment.

# %%
print(set(dp._targets_df['Sample number']).difference(set(dp.df['Sample number'])))
for sample in set(dp._targets_df['Sample number']).difference(set(dp.df['Sample number'])):
    range = dp._targets_df['Sample number'].values != sample
    dp._targets_df = dp._targets_df.iloc[range]
dp.save_targets_hdf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(set(dp._targets_df['Sample number']).difference(set(dp.df['Sample number'])))
#       2 for sample in set(dp._targets_df['Sample number']).difference(set(dp.df['Sample number'])):
#       3     range = dp._targets_df['Sample number'].values != sample
#
# NameError: name 'dp' is not defined

# %%
dp.group_samples()
dp.ungroup_samples()
print(dp.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dp.group_samples()
#       2 dp.ungroup_samples()
#       3 print(dp.to_string())
#
# NameError: name 'dp' is not defined

# %%
import pandas as pd
#print(pd.Categorical(dp.df.loc[:, 'Capillery size (um)'].values).categories)
#print(dp.df.loc[:, ['Capillery type', 'Capillery size (um)']].to_string())
#print(pd.Categorical(dp.df.loc[:, 'Protein'].values).categories)
print(pd.Categorical(dp.df.iloc[:, 12].to_numpy()).categories)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 import pandas as pd
#       2 #print(pd.Categorical(dp.df.loc[:, 'Capillery size (um)'].values).categories)
#       3 #print(dp.df.loc[:, ['Capillery type', 'Capillery size (um)']].to_string())
#       4 #print(pd.Categorical(dp.df.loc[:, 'Protein'].values).categories)
# ----> 5 print(pd.Categorical(dp.df.iloc[:, 12].to_numpy()).categories)
#
# NameError: name 'dp' is not defined

# %%
dp.to_excel('data_ungrouped.xlsx')
dp.to_hdf()
dp.group_samples()
dp.to_excel('data_grouped.xlsx')
dp.ungroup_samples()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dp.to_excel('data_ungrouped.xlsx')
#       2 dp.to_hdf()
#       3 dp.group_samples()
#
# NameError: name 'dp' is not defined

# %%
dp = DataProcessing()
dp.read_hdf()
print(dp.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dp = DataProcessing()
#       2 dp.read_hdf()
#       3 print(dp.to_string())
#
# NameError: name 'DataProcessing' is not defined

# %%
from data_processing import DataProcessing
dp = DataProcessing()
dp.targets_read_csv()
print(dp._targets_df.to_string())
print(dp._targets_df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 from data_processing import DataProcessing
#       2 dp = DataProcessing()
# ----> 3 dp.targets_read_csv()
#       4 print(dp._targets_df.to_string())
#       5 print(dp._targets_df.shape)
#
# File c:\Users\Erik\Repositories\Spinning-condition-and-mechanical-properties\src\data_processing.py:345, in DataProcessing.targets_read_csv(self, fname)
#     343 def targets_read_csv(self, fname: str | os.PathLike = 'targets.csv') -> None:
#     344     fp = os.path.join(self._data_dir, fname)
# --> 345     self._targets_df = pd.read_csv(fp)
#
# ...
